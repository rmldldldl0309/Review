# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as plb
import seaborn

# %%
# matplolib 한글 표시 설정
import matplotlib.font_manager as fm

# matplotlib의 글꼴 관리자에 특정 글꼴 추가
fe = fm.FontEntry(
    fname=r'font/NanumGothic.ttf',
    name='NanumGothic'
)
fm.fontManager.ttflist.insert(0, fe)

# pyplot에 matplotlib의 글꼴 관리자에 등록한 글꼴 적용
plt.rcParams.update({'font.family': 'NanumGothic', 'font.size':14})
# pyplot에서 '-'를 문자로 취급하도록 설정
plt.rcParams['axes.unicode_minus'] = False

# %%
iris = seaborn.load_dataset('iris') # 붓꽃 데이터
titanic = seaborn.load_dataset('titanic') # 타이타닉 데이터
tips = seaborn.load_dataset('tips') # 팁 데이터
flight = seaborn.load_dataset('flights') #여객기 데이터

# %% [markdown]
# ### seaborn을 활용한 차원 분포 플롯
# seaborn 패키지에서 제공해주는 여러 가지 메서드를 활용하여 간단하게 1차원 분포 플롯을 표시할 수 있다

# %% [markdown]
# #### 1차원 실수 분포 플롯
# seaborn 패키지는 히스토그램 형식과는 다른 커널 밀도, 러그 플롯을 제공한다
# `rugplot()`: 데이터 위치를 x축 위에 작은 슨분의로 표시 (러그 플롯)
# `kdeplot()`: 히스토그램과 비슷하지만 곡선형태로 표시 (커널 플롯)

# %%
data = iris.petal_length.values
data
# Out:
# array([1.4, 1.4, 1.3, 1.5, 1.4, 1.7, 1.4, 1.5, 1.4, 1.5, 1.5, 1.6, 1.4,
#        1.1, 1.2, 1.5, 1.3, 1.4, 1.7, 1.5, 1.7, 1.5, 1. , 1.7, 1.9, 1.6,
#        1.6, 1.5, 1.4, 1.6, 1.6, 1.5, 1.5, 1.4, 1.5, 1.2, 1.3, 1.4, 1.3,
#        1.5, 1.3, 1.3, 1.3, 1.6, 1.9, 1.4, 1.6, 1.4, 1.5, 1.4, 4.7, 4.5,
#        4.9, 4. , 4.6, 4.5, 4.7, 3.3, 4.6, 3.9, 3.5, 4.2, 4. , 4.7, 3.6,
#        4.4, 4.5, 4.1, 4.5, 3.9, 4.8, 4. , 4.9, 4.7, 4.3, 4.4, 4.8, 5. ,
#        4.5, 3.5, 3.8, 3.7, 3.9, 5.1, 4.5, 4.5, 4.7, 4.4, 4.1, 4. , 4.4,
#        4.6, 4. , 3.3, 4.2, 4.2, 4.2, 4.3, 3. , 4.1, 6. , 5.1, 5.9, 5.6,
#        5.8, 6.6, 4.5, 6.3, 5.8, 6.1, 5.1, 5.3, 5.5, 5. , 5.1, 5.3, 5.5,
#        6.7, 6.9, 5. , 5.7, 4.9, 6.7, 4.9, 5.7, 6. , 4.8, 4.9, 5.6, 5.8,
#        6.1, 6.4, 5.6, 5.1, 5.6, 6.1, 5.6, 5.5, 4.8, 5.4, 5.6, 5.1, 5.1,
#        5.9, 5.7, 5.2, 5. , 5.2, 5.4, 5.1])

# %%
seaborn.rugplot(data)
plt.title('러그 플롯')
plt.grid(True)
plt.show()

# %%
seaborn.kdeplot(data)
plt.title('커널 밀도 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 카운트 플롯
# seaborn 패키지의 `countplot()` 메서드로 각 카테고리 별 사이즈를 표시할 수 있다
# `countplot()`: 데이터 프레임만 사용가능
# `countplot(x='컬럼명', 'data=데이터프레임')`

# %%
seaborn.countplot(x='embark_town', data=titanic)
plt.title('타이타닉 카운트 플롯')
plt.grid(True)
plt.show()

# %%
seaborn.countplot(x='day', data=tips)
plt.title('요일별 팁')
plt.grid(True)
plt.show()

# %% [markdown]
# ###

# %% [markdown]
# ### seaborn 을 활용한 다차원 데이터
# 다차원 데이터는 3가지의 경우의 수를 가질 수 있다
# - 모든 데이터가 실수형
# - 모든 데이터가 카테고리형
# - 데이터가 실수형과 카테고리형이 섞여있는 경우

# %% [markdown]
# #### 2차원 실수형 데이터
# 데이터가 2차원이면서 모두 실수이면 `joinplot()` 메서드를 사용하여 표현할 수 있다
# `joinplot()`: 스캐터 플롯, 등고선 플롯 등을 나타낼 수 있고 양측의 히스토그램을 표현한다 (데이터프레임만 사용 가능)

# %%
seaborn.jointplot(data=iris, x='sepal_length', y='sepal_width', kind='scatter')
plt.title('꽃 받침의 길이와 넓이 비교ㅕ Join Plot', y=1.02)
plt.grid(True)
plt.show()

# %%
seaborn.jointplot(data=iris, x='sepal_length', y='sepal_width', kind='kde')
plt.title('꽃 받침의 길이와 넓이 비교 Join Plot', y=1.02)
plt.grid(True)
plt.show()

# %%
seaborn.jointplot(data=iris, x='sepal_length', y='sepal_width', kind='hist')
plt.title('꽃 받침의 길이와 넓이 비교ㅕ Join Plot', y=1.02)
plt.grid(True)
plt.show()

# %%
seaborn.jointplot(data=iris, x='sepal_length', y='sepal_width', kind='hex')
plt.title('꽃 받침의 길이와 넓이 비교ㅕ Join Plot', y=1.02)
plt.grid(True)
plt.show()

# %%
seaborn.jointplot(data=iris, x='sepal_length', y='sepal_width', kind='reg')
plt.title('꽃 받침의 길이와 넓이 비교ㅕ Join Plot', y=1.02)
plt.grid(True)
plt.show()

# %% [markdown]
# #### 다차원 실수형 데이터
# 3차원 이상의 데이터라면 `pairplot()` 메서드로 그리드형태의 스캐터 플롯의 행령을 만들어준다
# 같은 데이터가 만나는 대각선에는 각 데이터의 히스토그램을 표현

# %%
seaborn.pairplot(iris)
plt.suptitle('다차원 Pair Plot', y=1.02)
plt.show()

# %% [markdown]
# 카테고리형 데이터가 포함되어 있는 경우라면 `hue` 인수에 카테고리 변수 이름을 지정함

# %%
seaborn.pairplot(iris, hue='species', markers=['o', 's', 'D'])
plt.suptitle('다차원 Pair Plot', y=1.02)
plt.show()

# %% [markdown]
# #### 2차원 카테고리 데이터
# 데이터가 2차원이면서 모두 카테고리 앖이면 `heatmap() 메서드로 히트맵을 표현할 수 있다

# %%
titanic_size = titanic.pivot_table(
    index="class", columns="sex", aggfunc="size")
titanic_size
# Out:
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_8012\4072891046.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   titanic_size = titanic.pivot_table(
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
seaborn.heatmap(titanic_size, cmap=seaborn.light_palette("gray", as_cmap=True), annot=True, fmt="d")
plt.title("Heatmap")
plt.show()

# %% [markdown]
# #### 2차원 복합 데이터
# 데이터가 2차원이면서 실수 값과 카테고리 값이 섞여 있다면 기존 플롯 외의 다른 플롯을 사용할 수 있다

# %% [markdown]
# `barplot()`: 카테고리 값에 따른 실수 값의 평균과 표준 편차를 바 형태로 표시, 평균은 막대 그래프로, 편파는 에러바로 표현

# %%
seaborn.barplot(data=tips, x='day', y='total_bill')
plt.title('바 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `boxplot()`: 사분위수와 아웃라이어라는 데이터를 표현하는 방법

# %%
seaborn.boxenplot(data=tips, x='day', y='total_bill')
plt.title('박스 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `violinplot()`: 세로 방향으로 커널 밀도 히스토그램을 그려준다

# %%
seaborn.violinplot(data=tips, x='day', y='total_bill')
plt.title('바이올린 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `stripplot()`: 모든 데이터를 점으로 표시해서 보여준다

# %%
seaborn.stripplot(data=tips, x='day', y='total_bill')
plt.title('스트립 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `swarmplot()`: 스트립 플롯에서 데이터가 겹치는 부분을 겹치지지 않게 표현한다

# %%
seaborn.swarmplot(data=tips, x='day', y='total_bill')
plt.title('스웜 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# ### seaborn을 활용한 다차원 복합 데이터
# seaborn에서 제공해주는 플롯 메서드들은 `hue`인수를 통해 카테고리 값을 추가로 지정할 수 있다

# %%
seaborn.barplot(data=tips, x='day', y='total_bill', hue='sex')
plt.title('바 플롯')
plt.grid(True)
plt.show()

# %%
seaborn.violinplot(data=tips, x='day', y='total_bill', hue='sex')
plt.title('바이올린 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `stripplot()`, `swarmplot()`, `violinplot()`은 `split`, `dodge` 인수로 시각화 방법을 변경할 수 있다

# %%
seaborn.violinplot(data=tips, x='day', y='total_bill', hue='sex', split=True)
plt.title('바이올린 플롯')
plt.grid(True)
plt.show()

# %%
seaborn.swarmplot(data=tips, x='day', y='total_bill', hue='sex', dodge=True)
plt.title('스웜 플롯')
plt.grid(True)
plt.show()

# %% [markdown]
# `heatmap`으로도 두 개의 카테고리 값에 의한 실수 값 변화를 볼 수 있다

# %%
passengers = flight.pivot(index='month', columns='year', values='passengers')
seaborn.heatmap(passengers, annot=True, fmt='d', linewidths=1)
plt.title('히트맵으로 두 개의 카테고리 값 변화 비교')
plt.show()

# %% [markdown]
# ### seaborn을 활용한 catplot
# 색상과 행을 사용하여 3개 이상의 카테고리 값의 분포를 표현한다

# %%
data = titanic[titanic.survived.notnull()]

seaborn.catplot(data=data ,x='age', y='sex', hue='survived', row='class', kind='violin', split=True, height=2, aspect=4)
plt.suptitle('캣 플롯', y=1.02)
plt.show()

# %% [markdown]
# ### seaborn을 활용한 차트 겹치기
# 시각적 효과를 높이기 위해 여러 종류의 차트를 겹쳐서 표기

# %%
plt.title('박스 플롯 + 스트립 플롯')
seaborn.boxplot(data=tips, x='tip', y='day', whis=np.inf)
seaborn.stripplot(data=tips, x='tip', y='day')
plt.grid(True)
plt.show()

# %%
plt.title('바이올린 플롯 + 스웜 플롯')
seaborn.violinplot(data=tips, x='day' , y='total_bill', inner=None)
seaborn.swarmplot(data=tips, x='day', y='total_bill')
plt.grid(True)
plt.show()

# %% [markdown]
# ### seaborn을 활용한 스타일 변경
# seaborn 패키지는 matplotlib 에서 제공하는 기본 스타일이 아닌 특정 스타일로 변경할 수 있다
# `set` 메서드를 통해 색상, 틱 스타일 등을 변경할 수 있다
# `set_style()` 메서드를 통해 틱 스타일을 변경할 수 있다

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for number in range (1, 7):
        plt.plot(x, np.sin(x + number * 0.5) * (7 - number) * flip)
    plt.show()

# %%
seaborn.set_style('ticks')
sinplot()

# %%
seaborn.set_style('darkgrid')
sinplot()

# %% [markdown]
# ### pandas 패키지의 시각화 기능
# pandas 패키지의 series, dataframe 객체는 자체적으로 plot 메서드를 이용해서 시각화를 할 수 있다
# `plot()` 메서드의  `kind` 인수로 표현할 플롯을 지정할 수 있다
# 또는 plot 속성의 각 차트 메서드를 통해 바로 특정 플롯으로 표현할 수 있다

# %%
df = pd.DataFrame(np.random.randn(100,3), index=pd.date_range('2024-03-05', 
                    periods=100), 
                    columns=['A', 'B', 'C']).cumsum()
df
# Out:
#                    A         B         C
# 2024-03-05  0.966779  0.222302  0.061044
# 2024-03-06  1.479796  0.020760  0.128674
# 2024-03-07  1.189251 -0.425737 -0.157900
# 2024-03-08  0.950806 -0.363129 -0.502834
# 2024-03-09  1.306862  1.081083 -0.610504
# ...              ...       ...       ...
# 2024-06-08  7.973403  4.288961  6.534561
# 2024-06-09  6.510724  5.168218  6.795809
# 2024-06-10  6.082778  3.881562  7.975638
# 2024-06-11  8.038880  4.541247  7.906091
# 2024-06-12  8.037488  5.111618  7.932085
#
# [100 rows x 3 columns]

# %%
df.plot()
plt.title('데이터프레임 선 그래프')
plt.xlabel('시간')
plt.ylabel('Data')
plt.show()

# %%
data = iris.sepal_length[:20]
data.plot.bar(rot=0)
plt.title('시리즈 바 차트')
plt.xlabel('Data')
plt.ylabel('꽃 받침 길이')
plt.show()

# %%
data = iris[:5]
data.plot.bar(rot=0)
plt.xlabel('Data')
plt.ylabel('Feature')
plt.ylim(0, 7)
plt.grid(True)
plt.show()

# %%
data = iris.groupby(iris.species).mean()
data.columns.name = 'feature'
data.plot.bar(rot=0)
plt.title('각 종의 feature 별 평균')
plt.xlabel('평균')
plt.ylabel('종')
plt.ylim(0, 10)
plt.grid(True)
plt.show()

# %%
data = titanic.pclass.value_counts()
data.plot.pie(autopct='%.2f%%')
plt.title('선실별 승객 수 비율')
plt.axis('equal')
plt.show()

# %%
iris.plot.hist()
plt.title('각 feature 값들의 빈도 수 히스토그램')
plt.xlabel('Data')
plt.show()

# %%
iris.plot.kde()
plt.title('각 feature 값들의 빈도 수 커널 분포')
plt.xlabel('Data')
plt.show()

# %%
iris.plot.box()
plt.title('각 feature 값들의 빈도 수 박스 플롯')
plt.xlabel('Feature')
plt.ylabel('Data')
plt.show()

# %%
iris.boxplot(by='species')
plt.tight_layout()
plt.suptitle('Boxplot 메서드')
plt.show()
