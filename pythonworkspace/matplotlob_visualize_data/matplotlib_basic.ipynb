# %% [markdown]
# ### 데이터 시각화 패키지 matplotlib
# matplotlib 패키지는 파이썬에서 데이터를 차트 혹은 플롯으로 시각화하는 패키지
# - 선형 그래프(line plot)
# - 점 그래프(scatter plot)
# - 등고선(contour plot)
# - 표면도(surface plot)
# - 막대 그래프(bar chart)
# - 히스토그램(histogram)
# - 박스 그래프(box plot)

# %% [markdown]
# ### pyplot 하위 패키지
# 간단한 시각화 자료를 만들 때 사용되는 matplotlib 의 하위 패키지
# matplotlib 패키지를 직접 사용하지 않고 단순히 pyplot 만으로 시각화를 할 수 있다

# %% [markdown]
# ```python
# import matplotlib as mpl
# import matplotlib.pyplot as plt
# ```

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib as mpl
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
# matplolib 한글 표시 설정
import matplotlib.font_manager as fm

# matplotlib의 글꼴 관리자에 특정 글꼴 추가
fe = fm.FontEntry(
    fname=r'font/NanumGothic.ttf',
    name='NanumGothic'
)
fm.fontManager.ttflist.insert(0, fe)

# pyplot에 matplotlib의 글꼴 관리자에 등록한 글꼴 적용
plt.rcParams.update({'font.family': 'NanumGothic', 'font.size':14})
# pyplot에서 '-'를 문자로 취급하도록 설정
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 차트의 종류
#
# **막대 그래프**: 데이터의 카테고리별 값을 막대로 나타내는 방식 (수직 막대 그래프, 수평 막대 그래프)
# > 카테고리별로 비교할 때 주로 사용 (ex. 제품별 판매량, 지역별 인구수)
#
# **선 그래프**: 시간의 흐름에 따른 데이터 포인터를 선으로 연결하여 나타내는 방식
# > 시간의 흐름에 따라 비교할 때 주로 사용 (ex. 기온의 변화, 주식 가격)
#
# **파이 차트**: 전체에 대한 비율을 원형으로 나타내는 방식 (각 조각의 크기가 해당 부분의 비율)
# > 전체에 대한 비율을 비교할 때 주로 사용 (ex. 여론조사 결과)
#
# **산점도**: 두 변수 간의 상관 관계를 점들의 분포로 나타내는 방식
# > 두 변수의 상관 관계를 파악할 때 주로 사용됨 (ex. 키와 몸무게의 상관관계)
#
# **히스토그램**: 범위별로 그룹화하여 각 그룹에 속하는 데이터 포인터 수를 막대로 나타내는 방식
# > 데이터의 분포를 파악할 때 주로 사용됨 (ex. 시험 점수의 분포)
#
# **영역 그래프**: 선 그래프의 아래 영역에 색으로 채운 형태
# > 시간의 흐름에 따라 비교할 때 주로 사용, 변화량을 강조할 때 주로 사용 (ex. 누적 감염자, 누적 수출량)
#
# **박스 그래프**: 데이터의 분포를 나타내는 방식, 최소값, 최대값, 사분위를 나타내느 방식
# > 데이터의 이상치를 판단할 때 주로 사용

# %% [markdown]
# ### 라인 플롯 (선 그래프)
# 가장 기본적인 그래프로 데이터가 시간의 흐름, 순서에 따라 변할 때 사용됨
# pyplot 하위 패키지의 `plot()`메서드로 간단하게 생성 가능,
# 매개변수로 리스트 혹은 배열을 전달

# %%
plt.plot([1, 2, 4, 8, 16, 32])
plt.show()

# %%
plt.title('X 틱')
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 차트 스타일 지정
# plot 메서드에 특정한 문자열 매개변수를 전달하면 스타일을 변경할 수 있다

# %%
plt.title('rs-- 스타일 지정')
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32], 'cd--')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### `plot()`메서드의 스타일 매개변수
# - color (c): 선 색상
# - line width (lw): 선 굵기
# - line style (ls): 선 스타일
# - marker: 마커 종류
# - marker size (ms): 마커 크기
# - markeredgecolor (med): 마커 테두리 색상
# - markeredgewidth (mew): 마커 테두리 굵기
# - markerfacecolor (mfs): 마커 내부 색상

# %%
plt.title('스타일 지정')
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32], 
         lw=2, c='#12f2f2', ls=':', marker='*',ms=10, mfc='#009911'
         )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 차트 범위 지정
# `xlim()`, `ylim ()` 메서드로 x축과 t축의 상하한 값을 지정할 수 있다

# %%
plt.title('차트 범위 변경')
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32], 
         lw=2, c='#12f2f2', ls=':', marker='*',ms=10, mfc='#009911'
         )
plt.xlim(1995, 2030)
plt.ylim(-1, 40)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 틱 설정
# `xticks()`, `yticks()` 메서드로 틱의 위치나 라벨을 직접 지정할 수 있다

# %%
x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
plt.title('틱 설정')
plt.plot(x, c)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, 1], ['low', 'zero', 'high'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Grid 설정
# `grid()`메서드로 그리드를 표현할지 말지를 정할 수 있다

# %%
x = np.linspace(-np.pi, np.pi, 256)
c = np.cos(x)
plt.title('틱 설정')
plt.plot(x, c)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, 1], ['low', 'zero', 'high'])
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 여러 그래프 하나의 차트에 표현하기
# `plot()`메서드에 x, y, style 매개변수를 반복해서 전덜하여 여러 그래프를 하나의 차트에 표현할 수 있다
# 스타일 문자열 생략 불가능

# %%
t = np.arange(0., 5., 0.2)
plt.title('여러 그래프 표현')
plt.plot(t, t, 'r--', t, 0.5 * t ** 2, 'bs:', t, 0.2 * t **3, 'g^-')
plt.grid(True)
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible: 'bool | None' = None, which: "Literal['major', 'minor', 'both']" = 'major', axis: "Literal['both', 'x', 'y']" = 'both', **kwargs) -> 'None'>

# %% [markdown]
# ### 차트 겹치기
# `plot()`메서드를 중복하여 작성해서 차트를 겹칠 수 있다

# %%
plt.title('차트 겹치기')
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32], 
         lw=2, c='#12f2f2', ls=':', marker='*',ms=10, mfc='#009911'
         )
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [32, 16, 8, 4, 2, 1], 
         lw=2, c='#1256f2', ls=':', marker='o',ms=10, mfc='#5f1511'
         )
plt.xlim(1995, 2030)
plt.ylim(-1, 40)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 범례
# 여러 개의 그래프가 한 차트에 표시 될 때 각 그래프가 무엇을 의미하는지 보여주는
# 범례를 표현할 수 있음
# `legend()`메서드로 표현, 위치를 수동으로 지정하고 싶으면 `loc`매개변수를 사용함

# %%
plt.title('범례 표현')
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32], 
         lw=2, c='#12f2f2', ls=':', marker='*',ms=10, mfc='#009911', label='증가'
         )
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [32, 16, 8, 4, 2, 1], 
         lw=2, c='#1256f2', ls=':', marker='o',ms=10, mfc='#5f1511', label='감소'
         )
plt.legend(loc = 10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### x축, y축 라벨
# `xlabel()`, `ylabel()`메서드로 x축과 y축의 라벨을 표시할 수 있다

# %%
plt.title('축 라벨 표현')
plt.plot([2000, 2005, 2010, 2015, 2020, 2025], [1, 2, 4, 8, 16, 32], 
         lw=2, c='#12f2f2', ls=':', marker='*',ms=10, mfc='#009911'
         )
plt.xlabel('연도')
plt.ylabel('증가치')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 차트 그림의 구조
# matplotlib으로 그려지는 차트는 Figure객체, Axex객체, Axis객체로 구성된다
# Figure개체는, 하나 이상의 Axes객체를 포함하고 있고
# Axes객체는 2개이상의 Axis객체를 포함하고 있다
# - `Figure`: 차트가 그려지는 캔버스
# - `Axes`: 하나의 플롯(그래프)
# - `Axis`: 하나의 축

# %% [markdown]
# #### Figure 객체
# 모든 차트 그래프 결과는 Figure 객체에 포함되어 있다
# 내부 차트가 아닌 경우 하나의  Figure객체에 하나의 아이디와 원도우를 가진다
# 일반적으로 기본 파이썬에서 차트를 표시하면 Figure 하나당 하나의 윈도우를 가진다
# `plot()`메서드가 자동으로 Figure 객체를 생성하기 때문에 직접 생성하는 경우는 드물지만
# 여러개의 윈도우를 동시애 출력할 때나 차트 전체의 크기를 변경하고 싶을때 사용할 수 있다

# %%
f1 = plt.figure(figsize=(10,2))
plt.title('figure객체 사이즈 변경')
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# 현재 사용하고 있는 Figure 객체 얻으려면 `gcf()`메서드를 통해 얻을 수 있다

# %%
f1 = plt.figure(figsize=(10,2))
plt.title('figure객체 사이즈 변경')
plt.plot(np.random.randn(100))
plt.show()

f2 = plt.gcf()
print(id(f1))
print(id(f2))

plt.title('figure객체 사이즈 변경')
plt.plot(np.random.randn(100))

f3 = plt.gcf()
print(id(f3))
# Out:
# 2642892651984
# 2642857302672
# 2642857302672

# %% [markdown]
# ### `Axes`객체와 subplot
# 하나의 Figure 객체 안에 여러개의 Axes 객체를 생성하여 행렬 형태의 서브 플롯을 생성할 수 있다
# 이때 `subplot()`메서드를 사용하여 명시적으로 Axes 객체를 생성할 수 있다
# 그러나, pyplot의 `plot()`메서드를 바로 사용해도 Axes 객체를 생성할 수 있다

# %%
x1 = np.linspace(0, 5)
x2 = np.linspace(0, 2)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)
plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('2행 1열 서브 플롯 첫 번째')

plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'ro-')
plt.title('2행 2열 서브 플롯 두 번째')

plt.tight_layout()
plt.show()

# %% [markdown]
# `subplot()` 메서드의 (x, y, index) 의 인수를 (xyindex)로 붙여서 사용할 수 있다
#
# ex) `subplot(2, 2, 1)` → `subplot(221)`

# %%
plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title('첫 번째 플롯')

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title('두 번째 플롯')

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title('세 번째 플롯')

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title('네 번째 플롯')

plt.tight_layout()

# %% [markdown]
# `subplots(x, y)` 메서드로 복수의 axes 객체를 담은 배열을 생성할 수 있다
# `subplots(x, y` 메서드는 (figure, axes 배열) 튜플을 반환

# %%
figure, axes = plt.subplots(2, 2)

axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title('1행 1열')

axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title('1행 2열')

axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title('2행 1열')

axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title('2행 2열')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Axes 객체와 축
# `twinx()` 메서드로 x축을 공유하는 새로운 Axes 객체를 생성할 수 있다

# %%
figure, axes0 = plt.subplots()
axes1 = axes0.twinx()

axes0.set_title('x축을 공유하는 플롯')
axes0.plot([10, 5, 2, 9, 7], 'r-', label='y0')
axes0.set_ylabel('y0')

axes1.plot([100, 200, 220, 180, 120], 'g:', label='y1')
axes1.set_ylabel('y1')

axes0.set_xlabel('x축')
plt.show()
